# %% [markdown]
# # IMDb, binary classification

# %%
import keras
print(keras.__version__)
# Out:
# 2.10.0

# %%
from keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

print(train_data.shape)
print(train_data[0])
print(train_labels[0])
# Out:
# (25000,)
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# 1

# %%
#restore the sentence
word_index = imdb.get_word_index()
# print(word_index)

# %%
reverse_word_index = dict([value, key] for (key, value) in word_index.items())

decoded_review = ' '.join(reverse_word_index.get(i-3,'?') for i in train_data[0])
print(decoded_review)
# Out:
# ? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %%
# Preprocessing
# one-hot encoding

import numpy as np

def vectorize_sequence(sequences, dimension=10000): #set default value for parameter
    results = np.zeros((len(sequences), dimension))

    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1

    return results

X_train = vectorize_sequence(train_data)
X_test = vectorize_sequence(test_data)

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
# Build model
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#split validation data
X_val = X_train[:10000]
partial_X_train = X_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(partial_X_train, partial_y_train, epochs=20, batch_size=512, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.5459 - accuracy: 0.7598 - val_loss: 0.3952 - val_accuracy: 0.8684
# Epoch 2/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3168 - accuracy: 0.8993 - val_loss: 0.3131 - val_accuracy: 0.8842
# Epoch 3/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2299 - accuracy: 0.9270 - val_loss: 0.2835 - val_accuracy: 0.8884
# Epoch 4/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1798 - accuracy: 0.9417 - val_loss: 0.3220 - val_accuracy: 0.8689
# Epoch 5/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1457 - accuracy: 0.9542 - val_loss: 0.2785 - val_accuracy: 0.8885
# Epoch 6/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1208 - accuracy: 0.9633 - val_loss: 0.2955 - val_accuracy: 0.8845
# Epoch 7/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0991 - accuracy: 0.9689 - val_loss: 0.3168 - val_accuracy: 0.8810
# Epoch 8/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0812 - accuracy: 0.9785 - val_loss: 0.3235 - val_accuracy: 0.8826
# Epoch 9/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0653 - accuracy: 0.9839 - val_loss: 0.3491 - val_accuracy: 0.8799
# Epoch 10/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0547 - accuracy: 0.9879 - val_loss: 0.3785 - val_accuracy: 0.8773
# Epoch 11/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0430 - accuracy: 0.9904 - val_loss: 0.4154 - val_accuracy: 0.8753
# Epoch 12/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0336 - accuracy: 0.9925 - val_loss: 0.4388 - val_accuracy: 0.8691
# Epoch 13/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0276 - accuracy: 0.9950 - val_loss: 0.4639 - val_accuracy: 0.8738
# Epoch 14/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0201 - accuracy: 0.9968 - val_loss: 0.4960 - val_accuracy: 0.8680
# Epoch 15/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0177 - accuracy: 0.9969 - val_loss: 0.5259 - val_accuracy: 0.8666
# Epoch 16/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0120 - accuracy: 0.9989 - val_loss: 0.6099 - val_accuracy: 0.8565
# Epoch 17/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0079 - accuracy: 0.9996 - val_loss: 0.5898 - val_accuracy: 0.8694
# Epoch 18/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.6280 - val_accuracy: 0.8660
# Epoch 19/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.7216 - val_accuracy: 0.8559
# Epoch 20/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.6999 - val_accuracy: 0.8662

# %%
# Visualization
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc)+1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b-', label='Validation Loss')
plt.title('Train & Validation Loss')
plt.xlabel('Epoches')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.plot(epochs, acc, 'bo', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b-', label='Validation Accuracy')
plt.title('Train & Validation Accuracy')
plt.xlabel('Epoches')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# model reset and retrain
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(partial_X_train, partial_y_train, epochs=3, batch_size=512, validation_data=(X_val, y_val))
# Out:
# Epoch 1/3
# 30/30 [==============================] - 1s 23ms/step - loss: 0.5119 - accuracy: 0.7952 - val_loss: 0.4156 - val_accuracy: 0.8358
# Epoch 2/3
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3107 - accuracy: 0.9031 - val_loss: 0.3120 - val_accuracy: 0.8834
# Epoch 3/3
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2275 - accuracy: 0.9281 - val_loss: 0.2881 - val_accuracy: 0.8863

# %%
# use optimizer option
from keras import optimizers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(
    optimizer=optimizers.RMSprop(learning_rate=0.001), #to prevent overfitting
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(partial_X_train, partial_y_train, epochs=20, batch_size=512, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.5449 - accuracy: 0.7937 - val_loss: 0.4327 - val_accuracy: 0.8642
# Epoch 2/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3439 - accuracy: 0.9003 - val_loss: 0.3374 - val_accuracy: 0.8759
# Epoch 3/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2514 - accuracy: 0.9240 - val_loss: 0.2942 - val_accuracy: 0.8891
# Epoch 4/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1981 - accuracy: 0.9369 - val_loss: 0.2827 - val_accuracy: 0.8886
# Epoch 5/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1617 - accuracy: 0.9518 - val_loss: 0.2747 - val_accuracy: 0.8902
# Epoch 6/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1349 - accuracy: 0.9597 - val_loss: 0.3238 - val_accuracy: 0.8705
# Epoch 7/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1149 - accuracy: 0.9661 - val_loss: 0.2934 - val_accuracy: 0.8857
# Epoch 8/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0951 - accuracy: 0.9735 - val_loss: 0.3171 - val_accuracy: 0.8835
# Epoch 9/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0804 - accuracy: 0.9787 - val_loss: 0.3318 - val_accuracy: 0.8826
# Epoch 10/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0698 - accuracy: 0.9823 - val_loss: 0.3450 - val_accuracy: 0.8815
# Epoch 11/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0561 - accuracy: 0.9881 - val_loss: 0.3816 - val_accuracy: 0.8702
# Epoch 12/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0471 - accuracy: 0.9912 - val_loss: 0.3847 - val_accuracy: 0.8773
# Epoch 13/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0386 - accuracy: 0.9929 - val_loss: 0.4141 - val_accuracy: 0.8730
# Epoch 14/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0307 - accuracy: 0.9943 - val_loss: 0.4428 - val_accuracy: 0.8752
# Epoch 15/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0254 - accuracy: 0.9964 - val_loss: 0.4661 - val_accuracy: 0.8733
# Epoch 16/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0197 - accuracy: 0.9973 - val_loss: 0.4925 - val_accuracy: 0.8735
# Epoch 17/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0149 - accuracy: 0.9986 - val_loss: 0.5220 - val_accuracy: 0.8696
# Epoch 18/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0117 - accuracy: 0.9989 - val_loss: 0.5810 - val_accuracy: 0.8610
# Epoch 19/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0094 - accuracy: 0.9995 - val_loss: 0.5962 - val_accuracy: 0.8676
# Epoch 20/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0074 - accuracy: 0.9994 - val_loss: 0.6290 - val_accuracy: 0.8678

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc)+1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b-', label='Validation Loss')
plt.title('Training & Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.plot(epochs, acc, 'bo', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b-', label='Validation Accuracy')
plt.title('Train & Validation Accuracy')
plt.xlabel('Epoches')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
